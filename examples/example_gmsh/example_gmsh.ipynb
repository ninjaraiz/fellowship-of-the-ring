# %% [markdown]
# ## DEVELOPING AN AIRFOIL MESH FROM GMSH 4.13.1

# %%
import sys
# sys.path.append('/home/m.jaraiz/repos/pyLowOrder')
sys.path.append('/home/migueljaraiz/anaconda3/repos/pyLowOrder')
from FotR import ARAGORN
from FotR.solver_tools import GmshCase
import shutil

try:
    shutil.rmtree('./examples/case002')
except:
    print('No está')

# %%
runner = ARAGORN(timeout=None)
script_path = './gmsh_files/script_geo_v4.geo'
# script_path = '/home/m.jaraiz/Documentos/DATASETS/data_TIFON/gmsh_files/script_geo_v4.geo'

case = (
    GmshCase(script_path, workdir="./case001")
    .set_dimension(3)
    .set_format("msh2")
)
print(case.get_executable())

# %%
result = case.run(runner, run_id="airfoil_001")

print(result)

# %%
case.plot(mode="auto")

# %%
result = runner.run(
    script=script_path,
    program="gmsh",
    stdin_mode=False,
    extra_args=["-3", "-o", "mesh.msh"],
    n_cpus=8
)

# %%
eta = 5e-5
n_layers = 7
t = 0.011323999613523483
thickness = 0.05*t
r = 1.1

th = eta * (r**n_layers - 1)/(r-1)

print('th:', th, '\tmax_elem:', eta*r**n_layers)
print(thickness)
