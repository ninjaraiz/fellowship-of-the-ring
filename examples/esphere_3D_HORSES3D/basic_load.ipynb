# %%
# Cargar pylom manualmente si no está el paquete pyLOM en el environment cargado (to Copilot):
try:
    import pyLOM
    print('Environment with pylom instaled')
except ImportError:
    import sys
    sys.path.append('/home/m.jaraiz/repos/pyLowOrder/')
from FotR import FRODO, SAM
import os
# Out:
# 0 Warning! Import - NVTX not present!

# %%
db = FRODO(
    root_dir = '/home/m.jaraiz/Documentos/COMAC/my_ESPHERE_1',
    format = 'HORSES3D',
    strict=False
)
# Out:
#  NEW HORSES3D SIMULATION WILL BE LOADED FROM /home/m.jaraiz/Documentos/COMAC/my_ESPHERE_1
# INFO: no 'metadata/cases_metadata.json' found. Case discovery will rely solely on the 'outputs/' folder structure and the .control files inside it.
#
#
# 	WARNING: No Sets class for this format. Sets methods will not be available.
#
#
# 	WARNING: No Residuals class for this format. Residuals methods will not be available.
#
#
# 	WARNING: No Stats class for this format. Stats methods will not be available.
#
# 1 simulation found.
# Parse took: 0.0085 s
# /home/m.jaraiz/repos/fellowship-of-the-ring/FotR/characters/readers/horses3d.py:486: UserWarning: Case 'M_0.3_re_200', control 'file_control_p1.control': declared solution file 'RESULTS/my_esphere_v2g2p1.hsol' not found on disk.
#   warnings.warn(msg, UserWarning)
# /home/m.jaraiz/repos/fellowship-of-the-ring/FotR/characters/readers/horses3d.py:486: UserWarning: Case 'M_0.3_re_200', control 'file_control_p3.control': declared solution file 'RESULTS/my_esphere_v2g2p3.hsol' not found on disk.
#   warnings.warn(msg, UserWarning)
# /home/m.jaraiz/repos/fellowship-of-the-ring/FotR/characters/readers/horses3d.py:592: UserWarning: Case 'M_0.3_re_200': solution p=1 violates p >= g (g=2).
#   warnings.warn(msg, UserWarning)

# %%
SAM.DictVisualizer.rich_tree(db.sim_metadata)
# Out:
# root
# └── M_0.3_re_200
#     ├── case_idx
#     │   └── 0
#     ├── path
#     │   └── /home/m.jaraiz/Documentos/COMAC/my_ESPHERE_1/outputs/M_0.3_re_200
#     ├── design_vars
#     ├── mesh
#     │   ├── file
#     │   │   └── MESH/my_esphere_v2g2_mesh.h5
#     │   └── g
#     │       └── 2
#     └── solutions
#         ├── 1
#         │   ├── control_file
#         │   │   └── file_control_p1.control
#         │   ├── polynomial_order
#         │   │   └── 1
#         │   ├── solution_file
#         │   │   └── RESULTS/my_esphere_v2g2p1.hsol
#         │   ├── residuals_file
#         │   │   └── None
#         │   ├── residuals_found
#         │   │   └── False
#         │   ├── restart
#         │   │   └── False
#         │   ├── restart_file
#         │   │   └── RESULTS/my_esphere_pre.hsol
#         │   ├── restart_polorder
#         │   │   └── 1
#         │   ├── params
#         │   │   ├── flow_equations
#         │   │   │   └── NS
#         │   │   ├── mach_number
#         │   │   │   └── 0.3
#         │   │   ├── reynolds_number
#         │   │   │   └── 200.0
#         │   │   ├── aoa_theta
#         │   │   │   └── 0.0
#         │   │   ├── aoa_phi
#         │   │   │   └── 0.0
#         │   │   ├── number_of_time_steps
#         │   │   │   └── 100000.0
#         │   │   ├── output_interval
#         │   │   │   └── 1000.0
#         │   │   ├── convergence_tolerance
#         │   │   │   └── 1e-10
#         │   │   ├── simulation_type
#         │   │   │   └── time-accurate
#         │   │   └── final_time
#         │   │       └── 1600.0
#         │   ├── valid
#         │   │   └── False
#         │   └── issues
#         │       └── ["Case 'M_0.3_re_200', control 'file_control_p1.control': declared solution file
#         │           'RESULTS/my_esphere_v2g2p1.hsol' not found on disk.", "Case 'M_0.3_re_200': solution p=1
#         │           violates p >= g (g=2)."]
#         ├── 2
#         │   ├── control_file
#         │   │   └── file_control_p2.control
#         │   ├── polynomial_order
#         │   │   └── 2
#         │   ├── solution_file
#         │   │   └── RESULTS/my_esphere_v2g2p2.hsol
#         │   ├── residuals_file
#         │   │   └── RESULTS/my_esphere_v2g2p2.residuals
#         │   ├── residuals_found
#         │   │   └── True
#         │   ├── restart
#         │   │   └── False
#         │   ├── restart_file
#         │   │   └── RESULTS/my_esphere_v2g2p1.hsol
#         │   ├── restart_polorder
#         │   │   └── 1
#         │   ├── params
#         │   │   ├── flow_equations
#         │   │   │   └── NS
#         │   │   ├── mach_number
#         │   │   │   └── 0.3
#         │   │   ├── reynolds_number
#         │   │   │   └── 200.0
#         │   │   ├── aoa_theta
#         │   │   │   └── 0.0
#         │   │   ├── aoa_phi
#         │   │   │   └── 0.0
#         │   │   ├── number_of_time_steps
#         │   │   │   └── 1000000.0
#         │   │   ├── output_interval
#         │   │   │   └── 10000.0
#         │   │   ├── convergence_tolerance
#         │   │   │   └── 1e-10
#         │   │   ├── simulation_type
#         │   │   │   └── time-accurate
#         │   │   └── final_time
#         │   │       └── 1600.0
#         │   ├── valid
#         │   │   └── True
#         │   └── issues
#         │       └── []
#         └── 3
#             ├── control_file
#             │   └── file_control_p3.control
#             ├── polynomial_order
#             │   └── 3
#             ├── solution_file
#             │   └── RESULTS/my_esphere_v2g2p3.hsol
#             ├── residuals_file
#             │   └── None
#             ├── residuals_found
#             │   └── False
#             ├── restart
#             │   └── True
#             ├── restart_file
#             │   └── RESULTS/my_esphere_v2g2p2.hsol
#             ├── restart_polorder
#             │   └── 2
#             ├── params
#             │   ├── flow_equations
#             │   │   └── NS
#             │   ├── mach_number
#             │   │   └── 0.3
#             │   ├── reynolds_number
#             │   │   └── 200.0
#             │   ├── aoa_theta
#             │   │   └── 0.0
#             │   ├── aoa_phi
#             │   │   └── 0.0
#             │   ├── number_of_time_steps
#             │   │   └── 1000000.0
#             │   ├── output_interval
#             │   │   └── 10000.0
#             │   ├── convergence_tolerance
#             │   │   └── 1e-10
#             │   ├── simulation_type
#             │   │   └── time-accurate
#             │   └── final_time
#             │       └── 1600.0
#             ├── valid
#             │   └── False
#             └── issues
#                 └── ["Case 'M_0.3_re_200', control 'file_control_p3.control': declared solution file
#                     'RESULTS/my_esphere_v2g2p3.hsol' not found on disk."]
